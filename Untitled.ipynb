# %%
import pandas as pd
import numpy as np
import seaborn
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("./UberDataset.csv")
df.columns
# Out:
# Index(['START_DATE', 'END_DATE', 'CATEGORY', 'START', 'STOP', 'MILES',
#        'PURPOSE'],
#       dtype='object')

# %%
df.shape
# Out:
# (1156, 7)

# %%
df.head(3)
# Out:
#          START_DATE          END_DATE  CATEGORY        START         STOP  \
# 0  01-01-2016 21:11  01-01-2016 21:17  Business  Fort Pierce  Fort Pierce
# 1  01-02-2016 01:25  01-02-2016 01:37  Business  Fort Pierce  Fort Pierce
# 2  01-02-2016 20:25  01-02-2016 20:38  Business  Fort Pierce  Fort Pierce
#
#    MILES          PURPOSE
# 0    5.1   Meal/Entertain
# 1    5.0              NaN
# 2    4.8  Errand/Supplies

# %%
df.drop(['START','STOP'], axis=1, inplace=True)

# %%
df
# Out:
#             START_DATE          END_DATE  CATEGORY    MILES          PURPOSE
# 0     01-01-2016 21:11  01-01-2016 21:17  Business      5.1   Meal/Entertain
# 1     01-02-2016 01:25  01-02-2016 01:37  Business      5.0              NaN
# 2     01-02-2016 20:25  01-02-2016 20:38  Business      4.8  Errand/Supplies
# 3     01-05-2016 17:31  01-05-2016 17:45  Business      4.7          Meeting
# 4     01-06-2016 14:42  01-06-2016 15:49  Business     63.7   Customer Visit
# ...                ...               ...       ...      ...              ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business      3.9   Temporary Site
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business     16.2          Meeting
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business      6.4   Temporary Site
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business     48.2   Temporary Site
# 1155            Totals               NaN       NaN  12204.7              NaN
#
# [1156 rows x 5 columns]

# %%
MD_x = df.iloc[:, 0:11]

# %%
column_means = np.round(MD_x.mean(axis=0), 2)
column_means
# Out:
# C:\Users\bhati\AppData\Local\Temp\ipykernel_10840\2821293920.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   column_means = np.round(MD_x.mean(axis=0), 2)
# MILES    21.12
# dtype: float64

# %%
value_counts = df['CATEGORY'].value_counts()

# Extract count for 'Business' and calculate count for other values
count_business = value_counts.get('Business', 0)
count_others = len(df) - count_business

# Create a DataFrame for plotting
plot_data = pd.DataFrame({'Category': ['Business', 'Others'], 'Count': [count_business, count_others]})

# Plot the bar chart
plot_data.plot(kind='bar', x='Category', y='Count', legend=False, color=['blue', 'orange'])
plt.title('Count of "Business" vs Other Categories')
plt.ylabel('Count')
plt.show()

# %%
df2 = pd.read_csv("./UberDataset2.csv")
df2
# Out:
#       Request id Pickup point  Driver id             Status  \
# 0            619      Airport        1.0     Trip Completed
# 1            867      Airport        1.0     Trip Completed
# 2           1807         City        1.0     Trip Completed
# 3           2532      Airport        1.0     Trip Completed
# 4           3112         City        1.0     Trip Completed
# ...          ...          ...        ...                ...
# 6740        6745         City        NaN  No Cars Available
# 6741        6752      Airport        NaN  No Cars Available
# 6742        6751         City        NaN  No Cars Available
# 6743        6754         City        NaN  No Cars Available
# 6744        6753      Airport        NaN  No Cars Available
#
#         Request timestamp       Drop timestamp
# 0         11/7/2016 11:51      11/7/2016 13:00
# 1         11/7/2016 17:57      11/7/2016 18:47
# 2          12/7/2016 9:17       12/7/2016 9:58
# 3         12/7/2016 21:08      12/7/2016 22:03
# ...

# %%
value_counts2 = df2['Pickup point'].value_counts()
plot_data = pd.DataFrame({'Pickup point': value_counts2.index, 'Count': value_counts2.values})
plot_data.plot(kind='bar', x='Pickup point', y='Count', legend=False, color='skyblue')
plt.title('Count of Each Point')
plt.ylabel('Count')
plt.show()

# %%
column_means = np.round(MD_x.mean(axis=0), 2)
column_means
# Out:
# C:\Users\bhati\AppData\Local\Temp\ipykernel_10840\2821293920.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   column_means = np.round(MD_x.mean(axis=0), 2)
# MILES    21.12
# dtype: float64

# %%
MD_x.drop(['START_DATE','END_DATE','PURPOSE'],axis=1,inplace=True)

# %%
MD_x.drop(['CATEGORY'],axis=1,inplace=True)

# %%
from sklearn.cluster import KMeans

# Set seed for reproducibility
np.random.seed(1234)

cluster_results = []
for n_clusters in range(2, 9):
    kmeans = KMeans(n_clusters=n_clusters, n_init=10, random_state=1234)
    labels = kmeans.fit_predict(MD_x)
    cluster_results.append(labels)

def relabel_clusters(labels):
    unique_labels = np.unique(labels)
    relabeled = np.zeros_like(labels)
    for i, label in enumerate(unique_labels):
        relabeled[labels == label] = i
    return relabeled

# Relabel each set of cluster results
relabel_cluster_results = [relabel_clusters(labels) for labels in cluster_results]

for idx, labels in enumerate(relabel_cluster_results):
    print(f"Number of Clusters: {idx + 2}")
    print(labels)
    print("-" * 30)
# Out:
# C:\Users\bhati\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=5.
#   warnings.warn(
# C:\Users\bhati\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=5.
#   warnings.warn(
# C:\Users\bhati\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=5.
#   warnings.warn(
# ...

# %%
from sklearn.mixture import GaussianMixture

np.random.seed(1234)
bic_scores = []
cluster_results = []
for n_components in range(2, 9):
    gmm = GaussianMixture(n_components=n_components, n_init=10, random_state=1234)
    gmm.fit(MD_x)
    bic_scores.append(gmm.bic(MD_x))
    labels = gmm.predict(MD_x)
    cluster_results.append(labels)

optimal_components = np.argmin(bic_scores) + 2  

print("Optimal Number of Components:", optimal_components)

optimal_cluster_labels = cluster_results[optimal_components - 2] 
print("Cluster Labels:")
print(optimal_cluster_labels)
# Out:
# C:\Users\bhati\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=5.
#   warnings.warn(
# C:\Users\bhati\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=5.
#   warnings.warn(
# C:\Users\bhati\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=5.
#   warnings.warn(
# ...

# %%
df3 = pd.read_csv("./sigma_cabs.csv")
df3
# Out:
#             Trip_ID  Trip_Distance Type_of_Cab  Customer_Since_Months  \
# 0       T0005689460           6.77           B                    1.0
# 1       T0005689461          29.47           B                   10.0
# 2       T0005689464          41.58         NaN                   10.0
# 3       T0005689465          61.56           C                   10.0
# 4       T0005689467          54.95           C                   10.0
# ...             ...            ...         ...                    ...
# 131657  T0005908509          11.72           D                    1.0
# 131658  T0005908510          74.81           C                    7.0
# 131659  T0005908512          40.17           C                   10.0
# 131660  T0005908513          46.88           B                    4.0
# 131661  T0005908514          31.96           A                    7.0
#
#         Life_Style_Index Confidence_Life_Style_Index Destination_Type  \
# ...

# %%
MD_x3 = df3.iloc[:, 0:11]

# %%
column_means = np.round(MD_x3.mean(axis=0), 2)
column_means
# Out:
# C:\Users\bhati\AppData\Local\Temp\ipykernel_10840\4157308802.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   column_means = np.round(MD_x3.mean(axis=0), 2)
# Trip_Distance               44.20
# Customer_Since_Months        6.02
# Life_Style_Index             2.80
# Customer_Rating              2.85
# Cancellation_Last_1Month     0.78
# Var1                        64.20
# Var2                        51.20
# dtype: float64
